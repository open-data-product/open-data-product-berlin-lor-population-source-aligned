# %% [markdown]
# # Berlin LOR Population (source-aligned) - Sample Notebook

# %% [markdown]
# ## Explore data

# %%
import pandas as pd        

# Read csv file
dataframe = pd.read_csv("./data/03-gold/berlin-lor-population-2024-02-csv/berlin-lor-population-2024-02-t4-planning-areas.csv")

# %%
# Display 5 first rows
dataframe.head()
# Out:
#         id  ...  inhabitants_from_undefined_percentage
# 0  1100101  ...                               3.369384
# 1  1100102  ...                               4.033380
# 2  1100103  ...                               3.839733
# 3  1100104  ...                               6.826568
# 4  1100205  ...                               1.377275
#
# [5 rows x 57 columns]

# %%
# Display dataframe info
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 542 entries, 0 to 541
# Data columns (total 57 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   id                                               542 non-null    int64
#  1   inhabitants                                      542 non-null    int64
#  2   inhabitants_from_european_union                  542 non-null    int64
#  3   inhabitants_from_france                          542 non-null    int64
#  4   inhabitants_from_greece                          542 non-null    int64
#  5   inhabitants_from_italy                           542 non-null    int64
#  6   inhabitants_from_austria                         542 non-null    int64
#  7   inhabitants_from_spain                           542 non-null    int64
#  8   inhabitants_from_poland                          542 non-null    int64
# ...

# %%
# Describe dataframe
dataframe.describe()
# Out:
#                  id  ...  inhabitants_from_undefined_percentage
# count  5.420000e+02  ...                             542.000000
# mean   6.547167e+06  ...                               4.907649
# std    3.362516e+06  ...                               3.181314
# min    1.100101e+06  ...                               0.000000
# 25%    3.601451e+06  ...                               2.199114
# 50%    6.300578e+06  ...                               4.416358
# 75%    9.301101e+06  ...                               6.586785
# max    1.260124e+07  ...                              16.149068
#
# [8 rows x 57 columns]
